# %% [markdown]
# <a href="https://colab.research.google.com/github/gutembergue-martins/dimensionalidade_em_imagens/blob/main/binariza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Binarização

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow  # Para exibir imagens no Colab

# %%
# Carrega a imagem
img = cv2.imread('/content/sample_data/image/img_lena_2.jpg')

# Verifica se a imagem foi carregada corretamente
if img is None:
    print("Erro: Não foi possível carregar a imagem. Verifique o caminho.")
else:
    # Converte para escala de cinza
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Binariza a imagem com um limiar de 127 (ajustável)
    _, img_bin = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)

    # Combina as duas imagens lado a lado para exibição
    resultado = np.hstack([img_gray, img_bin])

    # Exibe a imagem no Colab
    cv2_imshow(resultado)
# Out:
# <PIL.Image.Image image mode=L size=450x225>
